# %%
import folium

# %%
map=folium.Map(location=[30.305598,77.995834],zoom_start=10)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Marker(location=[30.305598,77.995834],popup="home",icon=folium.Icon(color='green', icon='tint', icon_color='white' )).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd

# %%
dataset=pd.read_excel("Suburbs.xlsx")

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'Suburb',
#        'Number of single-residential properties_number', 'Oct 2017\nkl/month',
#        'Month', 'Year', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
dataset.head()
# Out:
#    Unnamed: 0           Suburb  \
# 0           0          ATHLONE
# 1           1           AURORA
# 2           2       BANTRY BAY
# 3           3  BELLVILLE SOUTH
# 4           4        BERGVLIET
#
#    Number of single-residential properties_number  Oct 2017\nkl/month  \
# 0                                            2272                  11
# 1                                             426                  10
# 2                                             248                  13
# 3                                            2041                  11
# 4                                            1488                   8
#
#      Month  Year   Latitude  Longitude
# 0  October  2017 -33.967220  18.502140
# 1  October  2017 -32.705958  18.485135
# 2  October  2017 -33.927953  18.382592
# 3  October  2017 -33.920011  18.642819
# 4  October  2017 -34.047464  18.452499

# %%
dataset["Oct 2017\nkl/month"][0]
# Out:
# 11

# %%
place= dataset[ ["Latitude","Longitude"] ]

# %%
place.head()
# Out:
#     Latitude  Longitude
# 0 -33.967220  18.502140
# 1 -32.705958  18.485135
# 2 -33.927953  18.382592
# 3 -33.920011  18.642819
# 4 -34.047464  18.452499

# %%
place=place.values.tolist()

# %%
submap=folium.Map(location=[-33.967220,18.502140],zoom_start=10)

# %%
def lw(color):
    folium.Marker(
            location=point, 
            popup=dataset['Suburb'][i],
            icon=folium.Icon(color=color, icon='tint', icon_color='white' )
        ).add_to(submap)

# %%
i=0
for point in place:
    if dataset['Oct 2017\nkl/month'][i] >= 10:
        lw('red')
    else:
        lw('green')
    i+=1

# %%
submap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
submap.save("Suburbs_Map.html")

# %%
newmap=folium.Map(location=[30.305598,77.995834],zoom_start=15)

# %%
folium.Circle(radius=200,location=[30.305598,77.995834],popup="home",color="green",fill=True).add_to(newmap)

# %%
newmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
